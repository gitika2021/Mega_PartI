# %%
import numpy as np
import matplotlib.pyplot as plt
import shape_utils,gen_ldc_ratio_grid,genlc_with_grid
file = "/home/iit-t/Gitika/Github-Repositories/Abraham_Mega/Reanalysis_Git/Mega_PartII_Kepler/Mega_PartI/Test/Data/OM_Demo/1.npy"
sh = np.load(file)
idx_sel = np.array([1,2,5])

plt.imshow(sh[idx_sel[0]])
#plt.savefig("../demo_figs/img1.png")
plt.show()

plt.imshow(sh[idx_sel[1]])
#plt.savefig("../demo_figs/img2.png")
plt.show()

plt.imshow(sh[idx_sel[2]])
#plt.savefig("../demo_figs/img2.png")
plt.show()


maps_sorted = np.zeros((3,38,38))
maps_sorted[0] = sh[idx_sel[0]]
maps_sorted[1] = sh[idx_sel[1]]
maps_sorted[2] = sh[idx_sel[2]]

file2="/home/iit-t/Gitika/Github-Repositories/Abraham_Mega/Reanalysis_Git/Mega_PartII_Kepler/Mega_PartI/Test/Data/LC_Demo/proc/RsRp_2_2/1LC_hscaled_processed.npy"
lc2 = np.load(file2)
meta2 = np.load("/home/iit-t/Gitika/Github-Repositories/Abraham_Mega/Reanalysis_Git/Mega_PartII_Kepler/Mega_PartI/Test/Data/LC_Demo/proc/RsRp_2_2/1_meta.npy")
print(meta2[idx_sel[0]],meta2[idx_sel[1]],meta2[idx_sel[2]])
plt.plot(lc2[idx_sel[0],:])
plt.plot(lc2[idx_sel[1],:])
plt.plot(lc2[idx_sel[2],:])
#plt.savefig("../demo_figs/lc_rsrp2_img1_img2.png")
plt.show()

file5="/home/iit-t/Gitika/Github-Repositories/Abraham_Mega/Reanalysis_Git/Mega_PartII_Kepler/Mega_PartI/Test/Data/LC_Demo/proc/RsRp_5_5/1LC_hscaled_processed.npy"
lc5 = np.load(file5)
x = np.linspace(-1,1,lc5.shape[1])
#lc5 = np.array([(lc5[i]-np.min(lc5[i]))/(np.max(lc5[i])-np.min(lc5[i])) for i in range(lc5.shape[0])])
#print(np.min(lc5,axis=1))
#lc5 = (lc5-np.min(lc5,axis=1))/(np.max(lc5,axis=1)-np.min(lc5,axis=1))
meta5 = np.load("/home/iit-t/Gitika/Github-Repositories/Abraham_Mega/Reanalysis_Git/Mega_PartII_Kepler/Mega_PartI/Test/Data/LC_Demo/proc/RsRp_5_5/1_meta.npy")
print(meta5[idx_sel[0]],meta5[idx_sel[1]],meta5[idx_sel[2]])
plt.plot(x,lc5[idx_sel[0],:])
plt.plot(x,lc5[idx_sel[1],:])
plt.plot(x,lc5[idx_sel[2],:])
#plt.savefig("../demo_figs/lc_rsrp2_img1_img2.png")
plt.show()

file10="/home/iit-t/Gitika/Github-Repositories/Abraham_Mega/Reanalysis_Git/Mega_PartII_Kepler/Mega_PartI/Test/Data/LC_Demo/proc/RsRp_10_10/1LC_hscaled_processed.npy"
lc10 = np.load(file10)
meta10=np.load("/home/iit-t/Gitika/Github-Repositories/Abraham_Mega/Reanalysis_Git/Mega_PartII_Kepler/Mega_PartI/Test/Data/LC_Demo/proc/RsRp_10_10/1_meta.npy")
print(meta10[idx_sel[0]],meta10[idx_sel[1]],meta10[idx_sel[2]])
plt.plot(lc10[idx_sel[0],:])
plt.plot(lc10[idx_sel[1],:])
plt.plot(lc10[idx_sel[2],:])
#plt.savefig("../demo_figs/lc_rsrp10_img1_img2.png")
plt.show()

lc = lc2
lcs_sorted = np.zeros((3,lc.shape[1]))
lcs_sorted[0] = lc[idx_sel[0]]
lcs_sorted[1] = lc[idx_sel[1]]
lcs_sorted[2] = lc[idx_sel[2]]


outpath = "/home/iit-t/Gitika/Github-Repositories/Abraham_Mega/Reanalysis_Git/Mega_PartII_Kepler/Mega_PartI/Test/Data_For_Plots/"
np.save(outpath+"maps_set2.npy",maps_sorted)
np.save(outpath+"lcrs_set2.npy",lcs_sorted)

maps_path = f"/home/iit-t/Gitika/Github-Repositories/Abraham_Mega/Reanalysis_Git/Mega_PartII_Kepler/Mega_PartI/Test/Data/OM_PlotsMegPart1/1.npy"
maps = np.load(maps_path)
np.save(outpath+"maps_set1.npy",maps)
# Out:
# [0.5081 0.2238 2.    ] [0.4096 0.2602 2.    ] [0.52735806 0.16390605 2.        ]
# [0.5081 0.2238 5.    ] [0.4096 0.2602 5.    ] [0.52735806 0.16390605 5.        ]
# [ 0.5081  0.2238 10.    ] [ 0.4096  0.2602 10.    ] [ 0.52735806  0.16390605 10.        ]

# %%
# quick check for produced light curves
lc_dir="/home/iit-t/Gitika/Github-Repositories/Abraham_Mega/Reanalysis_Git/Mega_PartII_Kepler/Mega_PartI/Test/Data/LC_Demo1/proc/RsRp_2_5/"

lc_org = np.load(lc_dir+"1LC.npy")
lc_hcl = np.load(lc_dir+"1LC_hscaled.npy")
# idx = 3
# plt.plot(lc_org[idx])
# plt.plot(lc_hcl[idx])
# plt.show()
lc = np.load(lc_dir+"Binned_LC/"+"1LC0_binned.npz")
plt.plot(lc['time'],lc['flux'])
plt.show()

# %%
# quick check for produced light curves
lc_dir="/home/iit-t/Gitika/Github-Repositories/Abraham_Mega/Reanalysis_Git/Mega_PartII_Kepler/Mega_PartI/Test/Data/LC_Demo2/proc/RsRp_2_5/"

lc_org = np.load(lc_dir+"1LC.npy")
lc_hcl = np.load(lc_dir+"1LC_hscaled.npy")
# idx = 3
# plt.plot(lc_org[idx])
# plt.plot(lc_hcl[idx])
# plt.show()
lc = np.load(lc_dir+"Binned_LC/"+"1LC0_binned.npz")
plt.plot(lc['time'],lc['flux'])
plt.show()


# quick check for produced light curves
lc_dir="/home/iit-t/Gitika/Github-Repositories/Abraham_Mega/Reanalysis_Git/Mega_PartII_Kepler/Mega_PartI/Test/Data/LC_Demo3/proc/RsRp_2_5/"

lc_org = np.load(lc_dir+"1LC.npy")
lc_hcl = np.load(lc_dir+"1LC_hscaled.npy")
# idx = 3
# plt.plot(lc_org[idx])
# plt.plot(lc_hcl[idx])
# plt.show()
lc = np.load(lc_dir+"Binned_LC/"+"1LC0_binned.npz")
plt.plot(lc['time'],lc['flux'])
plt.show()
