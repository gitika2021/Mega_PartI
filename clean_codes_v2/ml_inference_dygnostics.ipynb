# %%
import numpy as np
import matplotlib.pyplot as plt
from paths import *

# %%
rsrp1 = 10
rsrp2 = 12

lc_train_path = Base_Dir + f"Data/Train/RsRp_{rsrp1}_{rsrp2}/train_10LC.npy"
lcs_train = np.load(lc_train_path)
idx = 0
plt.plot(lcs_train[idx])
plt.show()

lcpath_final = Base_Dir + f"Data/LC10/proc/RsRp_{rsrp1}_{rsrp2}/Binned_LC/light_curves_all_processed.npy"
#lcpath_final = Base_Dir + f"Data/LC10/proc/RsRp_{rsrp1}_{rsrp2}/Binned_LC/light_curves_all.npy"
lcs = np.load(lcpath_final)

idx = 0
plt.plot(lcs[idx])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 12
#      10 lcpath_final = Base_Dir + f"Data/LC10/proc/RsRp_{rsrp1}_{rsrp2}/Binned_LC/light_curves_all_processed.npy"
#      11 #lcpath_final = Base_Dir + f"Data/LC10/proc/RsRp_{rsrp1}_{rsrp2}/Binned_LC/light_curves_all.npy"
# ---> 12 lcs = np.load(lcpath_final)
#      14 idx = 0
#      15 plt.plot(lcs[idx])
#
# File ~/anaconda3/envs/genenv_gitika/lib/python3.10/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# ...
